# %%
from ncwrapper1 import ncwrapper

# %%
ncwrapper("H:\Storage\Documents\School\Graduate School\CYGNSS\cyd01.nc")
# Out:
#  ---- Print Variable and Global Attributes of a NetCDF file ----
#
# Global attributes:
# Conventions  =  CF-1.6, ACDD-1.3, ISO-8601
# standard_name_vocabulary  =  CF Standard Name Table v30
# project  =  CYGNSS
# featureType  =  trajectory
# ...
